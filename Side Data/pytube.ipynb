# %%
import pytube
import json

# %%
obj = pytube.Playlist("https://youtube.com/playlist?list=PLT1rvk7Trkw6txGo58goY2a6U341h9EqB&si=YxxZaG7MpmPKMcwR")

# %%
with open('sidebar.json','w') as f:
    json.dump(obj.sidebar_info,f,indent=2)

# %%
with open('initial playlist data.json','w') as f:
    json.dump(obj.initial_data,f,indent=2)

# %%
videos = obj.initial_data["contents"]["twoColumnBrowseResultsRenderer"]["tabs"][0]["tabRenderer"]["content"]["sectionListRenderer"]["contents"][0]["itemSectionRenderer"]["contents"][0]["playlistVideoListRenderer"]["contents"]

# %%
videos
# Out:
# [{'playlistVideoRenderer': {'videoId': 'rLeRxvRBirQ',
#    'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/rLeRxvRBirQ/hqdefault.jpg?sqp=-oaymwEiCKgBEF5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLC64dXF-12VjVslugvqTHpIgRulHQ',
#       'width': 168,
#       'height': 94},
#      {'url': 'https://i.ytimg.com/vi/rLeRxvRBirQ/hqdefault.jpg?sqp=-oaymwEiCMQBEG5IWvKriqkDFQgBFQAAAAAYASUAAMhCPQCAokN4AQ==&rs=AOn4CLCAM1kYAHlPcOxk2-0jJTUqGdmJ-Q',
#       'width': 196,
#       'height': 110},
#      {'url': 'https://i.ytimg.com/vi/rLeRxvRBirQ/hqdefault.jpg?sqp=-oaymwEjCPYBEIoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDEmpVRQar45hkiFR1wVM31PT0g9w',
#       'width': 246,
#       'height': 138},
#      {'url': 'https://i.ytimg.com/vi/rLeRxvRBirQ/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA7VCAHCDcqGdr5k7g-pdJjuF79IA',
#       'width': 336,
#       'height': 188}]},
# ...

# %%
videos_data = []
for video in videos:
    videos_data.append({
        'vidoe_id':video["playlistVideoRenderer"]["videoId"],
        'thumbnail':video["playlistVideoRenderer"]["thumbnail"]["thumbnails"][-1]["url"],
        'title':video["playlistVideoRenderer"]["title"]["runs"][0]["text"],
        'length':video["playlistVideoRenderer"]["lengthSeconds"],
        'views':video["playlistVideoRenderer"]["videoInfo"]["runs"][0],
        'date_ago':video["playlistVideoRenderer"]["videoInfo"]["runs"][2],
    })
videos_data
# Out:
# [{'vidoe_id': 'rLeRxvRBirQ',
#   'thumbnail': 'https://i.ytimg.com/vi/rLeRxvRBirQ/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLA7VCAHCDcqGdr5k7g-pdJjuF79IA',
#   'title': "Bella's Butterfly Goodbye! | NEW CoComelon Lane Episodes on Netflix | Full Episode",
#   'length': '438',
#   'views': {'text': '3.2M views'},
#   'date_ago': {'text': '2 months ago'}},
#  {'vidoe_id': 'bMZToYgCK7Q',
#   'thumbnail': 'https://i.ytimg.com/vi/bMZToYgCK7Q/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDKhTzK0i9BiFuw3DKLtV_6U7noEA',
#   'title': 'JJ Gets a Checkup | NEW CoComelon Lane Episodes on Netflix | Full Episode',
#   'length': '439',
#   'views': {'text': '3.9M views'},
#   'date_ago': {'text': '2 months ago'}},
#  {'vidoe_id': '-xFrz2Pe8fc',
#   'thumbnail': 'https://i.ytimg.com/vi/-xFrz2Pe8fc/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAnYpxPhh_Z7zTJo07_0uBKC79BmA',
# ...
